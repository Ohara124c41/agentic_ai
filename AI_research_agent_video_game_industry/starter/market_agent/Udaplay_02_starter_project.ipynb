# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 02 - Agent
#
# In this part of the project, you'll use your VectorDB to be part of your Agent as a tool.
#
# You're building UdaPlay, an AI Research Agent for the video game industry. The agent will:
# 1. Answer questions using internal knowledge (RAG)
# 2. Search the web when needed
# 3. Maintain conversation state
# 4. Return structured outputs
# 5. Store useful information for future use

# %% [markdown]
# ### Setup

# %%
# # Only needed for Udacity workspace

# import importlib.util
# import sys

# # Check if 'pysqlite3' is available before importing
# if importlib.util.find_spec("pysqlite3") is not None:
#     import pysqlite3
#     sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
# !pip install tavily-python pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tavily-python in c:\users\ohara\appdata\roaming\python\python312\site-packages (0.7.12)
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: requests in c:\users\ohara\appdata\roaming\python\python312\site-packages (from tavily-python) (2.32.3)
# Requirement already satisfied: tiktoken>=0.5.1 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from tavily-python) (0.12.0)
# Requirement already satisfied: httpx in c:\users\ohara\appdata\roaming\python\python312\site-packages (from tavily-python) (0.28.1)
# Collecting pdfminer.six==20251107 (from pdfplumber)
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.0.0-py3-none-win_amd64.whl.metadata (67 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from pdfminer.six==20251107->pdfplumber) (3.4.0)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20251107->pdfplumber)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from tiktoken>=0.5.1->tavily-python) (2025.11.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from requests->tavily-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from requests->tavily-python) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from requests->tavily-python) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\ohara\appdata\roaming\python\python312\site-packages (from httpx->tavily-python) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ohara\appdata\roaming\python\python312\site-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Collecting cffi>=2.0.0 (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from anyio->httpx->tavily-python) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\ohara\appdata\roaming\python\python312\site-packages (from anyio->httpx->tavily-python) (4.15.0)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading pdfplumber-0.11.8-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.6 MB 1.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 0.8/5.6 MB 1.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 0.8/5.6 MB 1.2 MB/s eta 0:00:05
#    --------- ------------------------------ 1.3/5.6 MB 1.2 MB/s eta 0:00:04
#    --------- ------------------------------ 1.3/5.6 MB 1.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.6 MB 1.2 MB/s eta 0:00:04
#    ------------- -------------------------- 1.8/5.6 MB 1.1 MB/s eta 0:00:04
#    -------------- ------------------------- 2.1/5.6 MB 1.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.4/5.6 MB 1.2 MB/s eta 0:00:03
#    ------------------ --------------------- 2.6/5.6 MB 1.2 MB/s eta 0:00:03
#    -------------------- ------------------- 2.9/5.6 MB 1.2 MB/s eta 0:00:03
#    -------------------- ------------------- 2.9/5.6 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.1/5.6 MB 1.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.1/5.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------ --------------- 3.4/5.6 MB 1.0 MB/s eta 0:00:03
#    ------------------------ --------------- 3.4/5.6 MB 1.0 MB/s eta 0:00:03
#    -------------------------- ------------- 3.7/5.6 MB 1.0 MB/s eta 0:00:02
#    --------------------------- ------------ 3.9/5.6 MB 995.1 kB/s eta 0:00:02
#    ----------------------------- ---------- 4.2/5.6 MB 1.0 MB/s eta 0:00:02
#    ------------------------------- -------- 4.5/5.6 MB 1.0 MB/s eta 0:00:02
#    --------------------------------- ------ 4.7/5.6 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 1.1 MB/s eta 0:00:00
# Downloading pypdfium2-5.0.0-py3-none-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.1 MB 932.9 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/3.1 MB 799.2 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/3.1 MB 799.2 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/3.1 MB 799.2 kB/s eta 0:00:03
#    ------------- -------------------------- 1.0/3.1 MB 699.0 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.3/3.1 MB 745.8 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.3/3.1 MB 745.8 kB/s eta 0:00:03
#    -------------------- ------------------- 1.6/3.1 MB 699.0 kB/s eta 0:00:03
#    -------------------- ------------------- 1.6/3.1 MB 699.0 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.8/3.1 MB 685.0 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.8/3.1 MB 685.0 kB/s eta 0:00:02
#    --------------------------- ------------ 2.1/3.1 MB 703.3 kB/s eta 0:00:02
#    ------------------------------ --------- 2.4/3.1 MB 725.7 kB/s eta 0:00:02
#    ------------------------------ --------- 2.4/3.1 MB 725.7 kB/s eta 0:00:02
#    --------------------------------- ------ 2.6/3.1 MB 740.3 kB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 749.0 kB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 758.4 kB/s eta 0:00:00
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.5 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.5 MB 796.8 kB/s eta 0:00:04
#    -------- ------------------------------- 0.8/3.5 MB 882.6 kB/s eta 0:00:04
#    ----------- ---------------------------- 1.0/3.5 MB 948.7 kB/s eta 0:00:03
#    ----------- ---------------------------- 1.0/3.5 MB 948.7 kB/s eta 0:00:03
#    ----------- ---------------------------- 1.0/3.5 MB 948.7 kB/s eta 0:00:03
#    -------------- ------------------------- 1.3/3.5 MB 828.3 kB/s eta 0:00:03
#    ----------------- ---------------------- 1.6/3.5 MB 864.6 kB/s eta 0:00:03
#    -------------------- ------------------- 1.8/3.5 MB 898.8 kB/s eta 0:00:02
#    ----------------------- ---------------- 2.1/3.5 MB 946.9 kB/s eta 0:00:02
#    ----------------------------- ---------- 2.6/3.5 MB 1.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 1.0 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.1/3.5 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.1/3.5 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.1/3.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 937.5 kB/s eta 0:00:00
# Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pypdfium2, pycparser, cffi, cryptography, pdfminer.six, pdfplumber
# Successfully installed cffi-2.0.0 cryptography-46.0.3 pdfminer.six-20251107 pdfplumber-0.11.8 pycparser-2.23 pypdfium2-5.0.0
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import json
import uuid
from pathlib import Path
from datetime import datetime
from typing import Any, Dict, List

import chromadb
from chromadb.utils import embedding_functions
from dotenv import load_dotenv
from tavily import TavilyClient
from typing_extensions import TypedDict

from lib.vector_db import VectorStore
from lib.state_machine import StateMachine, Step, EntryPoint, Termination, Run
from lib.llm import LLM
from lib.messages import SystemMessage, UserMessage
from lib.tooling import tool, Tool

# %%
ENV_PATH = Path(".env")

if not ENV_PATH.exists():
    raise FileNotFoundError(
        f"Expected environment file at {ENV_PATH.resolve()} with API keys."
    )

load_dotenv(ENV_PATH)

required_keys = ["OPENAI_API_KEY", "TAVILY_API_KEY"]
missing = [key for key in required_keys if not os.getenv(key)]
if missing:
    raise EnvironmentError(
        f"Missing required environment variables: {', '.join(missing)}"
    )

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")
CHROMA_OPENAI_API_KEY = os.getenv("CHROMA_OPENAI_API_KEY") or OPENAI_API_KEY
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL", "https://openai.vocareum.com/v1")

if not CHROMA_OPENAI_API_KEY:
    raise EnvironmentError(
        "Either CHROMA_OPENAI_API_KEY or OPENAI_API_KEY must be defined."
    )

print("Environment loaded. Keys detected for OpenAI/Tavily.")
# Out:
# Environment loaded. Keys detected for OpenAI/Tavily.

# %%
class PersistentMemoryStore:
    def __init__(self, path: Path, embedding_function):
        self.path = path
        self.path.mkdir(parents=True, exist_ok=True)
        self.client = chromadb.PersistentClient(path=str(self.path))
        self.collection = self.client.get_or_create_collection(
            name="udaplay_long_term_memory",
            embedding_function=embedding_function,
            metadata={"description": "Web knowledge captured by UdaPlay"},
        )

    def add(self, content: str, source: str, metadata: Dict[str, Any] | None = None) -> Dict[str, Any]:
        doc_id = str(uuid.uuid4())
        payload = {
            "memory_id": doc_id,
            "source": source,
            "captured_at": datetime.utcnow().isoformat(),
        }
        if metadata:
            payload.update(metadata)

        self.collection.add(ids=[doc_id], documents=[content], metadatas=[payload])
        return payload

    def search(self, query: str, limit: int = 3) -> List[Dict[str, Any]]:
        if self.collection.count() == 0:
            return []

        results = self.collection.query(
            query_texts=[query],
            n_results=limit,
            include=["documents", "metadatas", "distances"],
        )
        documents = results.get("documents", [[]])[0]
        metadatas = results.get("metadatas", [[]])[0]
        distances = results.get("distances", [[]])[0]
        ids = results.get("ids", [[]])[0]

        matches = []
        for doc_id, doc, meta, distance in zip(ids, documents, metadatas, distances):
            matches.append(
                {
                    "id": doc_id,
                    "content": doc,
                    "metadata": meta,
                    "similarity": 1 - distance if distance is not None else None,
                    "source": meta.get("source", "memory"),
                }
            )
        return matches


CHROMA_DB_PATH = Path("chromadb")
MEMORY_DB_PATH = CHROMA_DB_PATH / "memory_store"
CHROMA_DB_PATH.mkdir(exist_ok=True)
MEMORY_DB_PATH.mkdir(parents=True, exist_ok=True)

EMBEDDING_MODEL = "text-embedding-3-small"
vector_embedding_fn = embedding_functions.OpenAIEmbeddingFunction(
    api_key=CHROMA_OPENAI_API_KEY,
    model_name=EMBEDDING_MODEL,
    api_base=OPENAI_BASE_URL,
)
memory_embedding_fn = embedding_functions.OpenAIEmbeddingFunction(
    api_key=CHROMA_OPENAI_API_KEY,
    model_name=EMBEDDING_MODEL,
    api_base=OPENAI_BASE_URL,
)

chroma_client = chromadb.PersistentClient(path=str(CHROMA_DB_PATH))
collection = chroma_client.get_or_create_collection(
    name="udaplay_games",
    embedding_function=vector_embedding_fn,
    metadata={"description": "UdaPlay core knowledge base"},
)

vector_store = VectorStore(collection)
memory_store = PersistentMemoryStore(MEMORY_DB_PATH, memory_embedding_fn)

tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

answer_llm = LLM(model="gpt-4o-mini", temperature=0.2, api_key=OPENAI_API_KEY, base_url=OPENAI_BASE_URL)
evaluation_llm = LLM(model="gpt-4o-mini", temperature=0.0, api_key=OPENAI_API_KEY, base_url=OPENAI_BASE_URL)

print(f"Vector store ready with {collection.count()} documents.")
print("Long-term memory namespace initialized.")
# Out:
# Vector store ready with 22 documents.
# Long-term memory namespace initialized.

# %% [markdown]
# ### Tools

# %% [markdown]
# Build at least 3 tools:
# - retrieve_game: To search the vector DB
# - evaluate_retrieval: To assess the retrieval performance
# - game_web_search: If no good, search the web

# %% [markdown]
# #### Retrieve Game Tool

# %%
@tool(name="retrieve_game", description="Search the local knowledge base for video game facts.")
def retrieve_game(question: str, limit: int = 4) -> Dict[str, Any]:
    results = vector_store.query(query_texts=[question], n_results=limit)
    documents = results.get("documents", [[]])[0]
    metadatas = results.get("metadatas", [[]])[0]
    distances = results.get("distances", [[]])[0]

    matches = []
    for idx, (doc, meta, distance) in enumerate(zip(documents, metadatas, distances), start=1):
        matches.append(
            {
                "rank": idx,
                "id": meta.get("Name", f"doc_{idx}"),
                "document": doc,
                "metadata": meta,
                "distance": distance,
                "similarity": 1 - distance if distance is not None else None,
            }
        )

    return {
        "query": question,
        "matches": matches,
        "source": "vector_db",
    }

# %% [markdown]
# #### Evaluate Retrieval Tool

# %%
@tool(name="evaluate_retrieval", description="Score the quality of retrieved documents and decide on fallback needs.")
def evaluate_retrieval(question: str, matches: List[Dict[str, Any]]) -> Dict[str, Any]:
    if not matches:
        return {
            "summary": "No local matches were returned.",
            "confidence": 0.0,
            "needs_web_search": True,
            "supporting_fact_ids": [],
        }

    context_lines = [
        f"{item['rank']}. {item['metadata'].get('Name')} ("
        f"{item['metadata'].get('Platform')}) - {item['metadata'].get('Publisher')}"
        f" | {item['document']}"
        for item in matches
    ]

    evaluation_prompt = (
        "You are the quality gate for a retrieval pipeline. "
        "Return valid JSON with fields summary (string), confidence (0-1 float), "
        "needs_web_search (boolean), and supporting_fact_ids (list of integers referencing the provided context order). "
        "Choose needs_web_search=True when the question is unanswered or context is missing critical facts."
    )

    messages = [
        SystemMessage(content=evaluation_prompt),
        UserMessage(
            content=json.dumps(
                {"question": question, "context": context_lines},
                ensure_ascii=False,
                indent=2,
            )
        ),
    ]

    ai_message = evaluation_llm.invoke(messages)

    try:
        evaluation = json.loads(ai_message.content)
    except json.JSONDecodeError:
        evaluation = {
            "summary": ai_message.content,
            "confidence": max(matches[0].get("similarity") or 0.4, 0.4),
            "needs_web_search": True,
            "supporting_fact_ids": [],
        }

    evaluation["confidence"] = float(evaluation.get("confidence", 0.4))
    evaluation["needs_web_search"] = bool(evaluation.get("needs_web_search", True))
    evaluation.setdefault("supporting_fact_ids", [])
    return evaluation

# %%
@tool(name="game_web_search", description="Use Tavily to gather fresh information when local knowledge is insufficient.")
def game_web_search(question: str, max_results: int = 4) -> Dict[str, Any]:
    try:
        response = tavily_client.search(
            query=question,
            max_results=max_results,
            include_answer=True,
            include_domains=True,
            search_depth="basic",
        )
    except Exception as exc:
        return {
            "query": question,
            "error": str(exc),
            "results": [],
        }

    simplified_results = [
        {
            "title": item.get("title"),
            "url": item.get("url"),
            "content": item.get("content"),
            "score": item.get("score"),
        }
        for item in response.get("results", [])
    ]

    return {
        "query": question,
        "answer": response.get("answer"),
        "results": simplified_results,
    }

# %% [markdown]
# ### Agent

# %%
class GameAgentState(TypedDict, total=False):
    question: str
    retrieval: Dict[str, Any]
    evaluation: Dict[str, Any]
    needs_web_search: bool
    web_results: Dict[str, Any]
    memory_context: List[Dict[str, Any]]
    answer: str
    citations: List[Dict[str, str]]
    confidence: float
    history: List[Dict[str, Any]]


class GameResearchAgent:
    def __init__(
        self,
        retrieve_tool: Tool,
        evaluate_tool: Tool,
        web_tool: Tool,
        answer_llm: LLM,
        memory_store: PersistentMemoryStore,
    ):
        self.retrieve_tool = retrieve_tool
        self.evaluate_tool = evaluate_tool
        self.web_tool = web_tool
        self.answer_llm = answer_llm
        self.memory_store = memory_store
        self.history: List[Dict[str, Any]] = []
        self.traces: List[Run] = []
        self.workflow = self._build_workflow()

    def _build_workflow(self) -> StateMachine[GameAgentState]:
        machine = StateMachine(GameAgentState)
        entry = EntryPoint[GameAgentState]()
        retrieve = Step[GameAgentState]("retrieve", self._retrieve_step)
        evaluate = Step[GameAgentState]("evaluate", self._evaluate_step)
        web_search = Step[GameAgentState]("web_search", self._web_search_step)
        finalize = Step[GameAgentState]("finalize", self._finalize_step)
        termination = Termination[GameAgentState]()

        machine.add_steps([entry, retrieve, evaluate, web_search, finalize, termination])
        machine.connect(entry, retrieve)
        machine.connect(retrieve, evaluate)

        def route(state: GameAgentState):
            return web_search if state.get("needs_web_search") else finalize

        machine.connect(evaluate, [web_search, finalize], route)
        machine.connect(web_search, finalize)
        machine.connect(finalize, termination)
        return machine

    def _retrieve_step(self, state: GameAgentState) -> GameAgentState:
        question = state["question"]
        retrieval = self.retrieve_tool(question=question)
        memory_matches = self.memory_store.search(question)
        return {
            "retrieval": retrieval,
            "memory_context": memory_matches,
        }

    def _evaluate_step(self, state: GameAgentState) -> GameAgentState:
        matches = state.get("retrieval", {}).get("matches", [])
        evaluation = self.evaluate_tool(question=state["question"], matches=matches)
        return {
            "evaluation": evaluation,
            "needs_web_search": evaluation.get("needs_web_search", False),
        }

    def _web_search_step(self, state: GameAgentState) -> GameAgentState:
        question = state["question"]
        web_results = self.web_tool(question=question, max_results=4)

        for item in web_results.get("results", []):
            snippet = item.get("content")
            if not snippet:
                continue
            self.memory_store.add(
                content=snippet,
                source=item.get("url", "web"),
                metadata={
                    "title": item.get("title"),
                    "origin": "tavily",
                    "question": question,
                },
            )

        return {"web_results": web_results}

    def _finalize_step(self, state: GameAgentState) -> GameAgentState:
        question = state["question"]
        matches = state.get("retrieval", {}).get("matches", [])
        memory_matches = state.get("memory_context", [])
        web_results = state.get("web_results", {})
        evaluation = state.get("evaluation", {})

        context_segments: List[str] = []
        citation_sources: List[str] = []

        for match in matches:
            meta = match.get("metadata", {})
            citation = meta.get("Name") or match.get("id")
            snippet = (
                f"Local | {meta.get('Name')} ({meta.get('Platform')}, {meta.get('YearOfRelease')}) "
                f"- Publisher: {meta.get('Publisher')} | {match.get('document')}"
            )
            context_segments.append(snippet)
            citation_sources.append(citation)

        for memory_item in memory_matches:
            citation_sources.append(memory_item.get("source"))
            context_segments.append(
                f"Memory | Source: {memory_item.get('source')} | {memory_item.get('content')}"
            )

        for item in web_results.get("results", []):
            context_segments.append(
                f"Web | {item.get('title')} ({item.get('url')}): {item.get('content')}"
            )
            citation_sources.append(item.get("url"))

        if web_results.get("answer"):
            context_segments.append(f"Web Summary | {web_results['answer']}")

        if not context_segments:
            context_segments.append("No supporting context was available.")

        unique_sources: List[str] = []
        for source in citation_sources:
            if source and source not in unique_sources:
                unique_sources.append(source)

        source_catalog = (
            "\\n".join(
                [f"[{idx}] {source}" for idx, source in enumerate(unique_sources, start=1)]
            )
            if unique_sources
            else "[1] No supporting sources captured"
        )

        recent_history = self.history[-3:]
        history_text = (
            "\\n".join(
                [f"Q: {item['question']}\\nA: {item['answer']}" for item in recent_history]
            )
            if recent_history
            else "No previous turns."
        )

        payload = {
            "question": question,
            "context": "\\n\\n".join(context_segments),
            "source_catalog": source_catalog,
            "previous_turns": history_text,
        }

        system_prompt = (
            "You are UdaPlay, an analyst for the video game industry. "
            "Answer the question using ONLY the provided context. "
            "Cite sources with the provided labels (e.g., [1]) and clearly state "
            "when information is unavailable. End with a short bullet list of key facts."
        )

        messages = [
            SystemMessage(content=system_prompt),
            UserMessage(content=json.dumps(payload, ensure_ascii=False)),
        ]
        ai_message = self.answer_llm.invoke(messages)

        confidence = float(evaluation.get("confidence", 0.4))
        citations = [
            {"label": f"[{idx}]", "source": source}
            for idx, source in enumerate(unique_sources, start=1)
        ] if unique_sources else []

        answer = ai_message.content.strip()

        history_entry = {
            "question": question,
            "answer": answer,
            "citations": citations,
            "confidence": confidence,
        }
        self.history.append(history_entry)

        return {
            "answer": answer,
            "citations": citations,
            "confidence": confidence,
            "history": self.history,
        }

    def ask(self, question: str) -> Dict[str, Any]:
        initial_state: GameAgentState = {"question": question}
        run = self.workflow.run(initial_state)
        final_state = run.get_final_state() or {}
        final_state.setdefault("question", question)
        self.traces.append(run)
        return final_state

# %%
agent = GameResearchAgent(
    retrieve_tool=retrieve_game,
    evaluate_tool=evaluate_retrieval,
    web_tool=game_web_search,
    answer_llm=answer_llm,
    memory_store=memory_store,
)

sample_questions = [
    "Who developed FIFA 21?",
    "When was God of War Ragnarok released?",
    "What platform was Pokemon Red launched on?",
    "What is Rockstar Games working on right now?",
    "Who made Dark Souls 3?",
    "Who wrote the story for Nier Automata?",
    "What is the most recent Star Ocean game?",
    "Who is the main character of FFVII?",
]

agent_outputs = []
for question in sample_questions:
    print(f" >>> {question}")
    result = agent.ask(question)
    agent_outputs.append(result)
    print(result.get("answer", "No answer generated."))
    print("Confidence:", result.get("confidence"))
    print("Citations:", result.get("citations"))

agent_outputs
# Out:
#  >>> Who developed FIFA 21?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on FIFA 21 developer is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': 'Halo Infinite'}, {'label': '[2]', 'source': 'Minecraft'}, {'label': '[3]', 'source': "Marvel's Spider-Man 2"}, {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}]
#  >>> When was God of War Ragnarok released?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on God of War Ragnarok's release date is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': "Marvel's Spider-Man"}, {'label': '[2]', 'source': "Marvel's Spider-Man 2"}, {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'}, {'label': '[4]', 'source': 'Halo Infinite'}]
#  >>> What platform was Pokemon Red launched on?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on the platform for Pokémon Red is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': 'Pokémon Gold and Silver'}, {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'}, {'label': '[3]', 'source': 'Super Mario 64'}, {'label': '[4]', 'source': 'Super Mario World'}]
#  >>> What is Rockstar Games working on right now?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on Rockstar Games' current projects is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'}, {'label': '[2]', 'source': "Marvel's Spider-Man"}, {'label': '[3]', 'source': 'Halo Infinite'}, {'label': '[4]', 'source': 'Minecraft'}]
#  >>> Who made Dark Souls 3?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include information about who made Dark Souls 3. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on the developer of Dark Souls 3 is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': "Marvel's Spider-Man 2"}, {'label': '[2]', 'source': 'Gran Turismo 5'}, {'label': '[3]', 'source': 'Pokémon Ruby and Sapphire'}, {'label': '[4]', 'source': "Marvel's Spider-Man"}]
#  >>> Who wrote the story for Nier Automata?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include information about who wrote the story for Nier Automata. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on the story writer for Nier Automata is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'}, {'label': '[2]', 'source': "Marvel's Spider-Man 2"}, {'label': '[3]', 'source': 'Mario Kart 8 Deluxe'}, {'label': '[4]', 'source': 'Halo Infinite'}]
#  >>> What is the most recent Star Ocean game?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include any information about the most recent Star Ocean game. Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on the most recent Star Ocean game is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': 'Pokémon Ruby and Sapphire'}, {'label': '[2]', 'source': 'Pokémon Gold and Silver'}, {'label': '[3]', 'source': 'Halo Infinite'}, {'label': '[4]', 'source': 'Gran Turismo 5'}]
#  >>> Who is the main character of FFVII?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: evaluate
# [StateMachine] Executing step: web_search
# [StateMachine] Executing step: finalize
# [StateMachine] Terminating: __termination__
# The provided context does not include information about the main character of Final Fantasy VII (FFVII). Therefore, I cannot answer your question based on the available data.
#
# Key facts:
# - No information on the main character of FFVII is available in the context provided.
# Confidence: 0.0
# Citations: [{'label': '[1]', 'source': 'Super Mario World'}, {'label': '[2]', 'source': 'Super Mario 64'}, {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'}, {'label': '[4]', 'source': 'Super Smash Bros. Melee'}]
# [{'question': 'Who developed FIFA 21?',
#   'retrieval': {'query': 'Who developed FIFA 21?',
#    'matches': [{'rank': 1,
#      'id': 'Halo Infinite',
#      'document': "[Xbox Series X|S] Halo Infinite (2021) - The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#      'metadata': {'Publisher': 'Xbox Game Studios',
#       'Description': "The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#       'YearOfRelease': 2021,
#       'Platform': 'Xbox Series X|S',
#       'Name': 'Halo Infinite',
#       'Genre': 'First-person shooter'},
#      'distance': 0.6915041208267212,
#      'similarity': 0.3084958791732788},
#     {'rank': 2,
#      'id': 'Minecraft',
#      'document': '[Xbox One] Minecraft (2014) - A sandbox game that allows players to build and explore infinite worlds, fostering creativity and adventure.',
#      'metadata': {'Publisher': 'Mojang Studios',
#       'Genre': 'Sandbox, Survival',
#       'Platform': 'Xbox One',
#       'YearOfRelease': 2014,
#       'Description': 'A sandbox game that allows players to build and explore infinite worlds, fostering creativity and adventure.',
#       'Name': 'Minecraft'},
#      'distance': 0.7047427892684937,
#      'similarity': 0.29525721073150635},
#     {'rank': 3,
#      'id': "Marvel's Spider-Man 2",
#      'document': "[PlayStation 5] Marvel's Spider-Man 2 (2023) - The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.",
#      'metadata': {'Publisher': 'Sony Interactive Entertainment',
#       'Name': "Marvel's Spider-Man 2",
#       'Genre': 'Action-adventure',
#       'Description': 'The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.',
#       'Platform': 'PlayStation 5',
#       'YearOfRelease': 2023},
#      'distance': 0.7169698476791382,
#      'similarity': 0.2830301523208618},
#     {'rank': 4,
#      'id': 'Mario Kart 8 Deluxe',
#      'document': '[Nintendo Switch] Mario Kart 8 Deluxe (2017) - An enhanced version of Mario Kart 8, featuring new characters, tracks, and improved gameplay mechanics.',
#      'metadata': {'Genre': 'Racing',
#       'Name': 'Mario Kart 8 Deluxe',
#       'Description': 'An enhanced version of Mario Kart 8, featuring new characters, tracks, and improved gameplay mechanics.',
#       'Platform': 'Nintendo Switch',
#       'Publisher': 'Nintendo',
#       'YearOfRelease': 2017},
#      'distance': 0.735100269317627,
#      'similarity': 0.26489973068237305}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The developer of FIFA 21 is not mentioned in the provided context.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'Who developed FIFA 21?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#   'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#    {'label': '[2]', 'source': 'Minecraft'},
#    {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#    {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0}]},
#  {'question': 'When was God of War Ragnarok released?',
#   'retrieval': {'query': 'When was God of War Ragnarok released?',
#    'matches': [{'rank': 1,
#      'id': "Marvel's Spider-Man",
#      'document': "[PlayStation 4] Marvel's Spider-Man (2018) - An open-world superhero game that lets players swing through New York City as Spider-Man, battling iconic villains.",
#      'metadata': {'YearOfRelease': 2018,
#       'Genre': 'Action-adventure',
#       'Publisher': 'Sony Interactive Entertainment',
#       'Description': 'An open-world superhero game that lets players swing through New York City as Spider-Man, battling iconic villains.',
#       'Name': "Marvel's Spider-Man",
#       'Platform': 'PlayStation 4'},
#      'distance': 0.6936237812042236,
#      'similarity': 0.30637621879577637},
#     {'rank': 2,
#      'id': "Marvel's Spider-Man 2",
#      'document': "[PlayStation 5] Marvel's Spider-Man 2 (2023) - The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.",
#      'metadata': {'YearOfRelease': 2023,
#       'Platform': 'PlayStation 5',
#       'Name': "Marvel's Spider-Man 2",
#       'Description': 'The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.',
#       'Publisher': 'Sony Interactive Entertainment',
#       'Genre': 'Action-adventure'},
#      'distance': 0.7111552953720093,
#      'similarity': 0.2888447046279907},
#     {'rank': 3,
#      'id': 'Grand Theft Auto: San Andreas',
#      'document': "[PlayStation 2] Grand Theft Auto: San Andreas (2004) - An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#      'metadata': {'Genre': 'Action-adventure',
#       'Description': "An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#       'Publisher': 'Rockstar Games',
#       'Name': 'Grand Theft Auto: San Andreas',
#       'YearOfRelease': 2004,
#       'Platform': 'PlayStation 2'},
#      'distance': 0.7703596949577332,
#      'similarity': 0.22964030504226685},
#     {'rank': 4,
#      'id': 'Halo Infinite',
#      'document': "[Xbox Series X|S] Halo Infinite (2021) - The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#      'metadata': {'Platform': 'Xbox Series X|S',
#       'Name': 'Halo Infinite',
#       'Publisher': 'Xbox Game Studios',
#       'Description': "The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#       'Genre': 'First-person shooter',
#       'YearOfRelease': 2021},
#      'distance': 0.7751376032829285,
#      'similarity': 0.22486239671707153}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The release date for God of War Ragnarok is not provided in the context.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'When was God of War Ragnarok released?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#   'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#    {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#    {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#    {'label': '[4]', 'source': 'Halo Infinite'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0}]},
#  {'question': 'What platform was Pokemon Red launched on?',
#   'retrieval': {'query': 'What platform was Pokemon Red launched on?',
#    'matches': [{'rank': 1,
#      'id': 'Pokémon Gold and Silver',
#      'document': '[Game Boy Color] Pokémon Gold and Silver (1999) - Second-generation Pokémon games introducing new regions, Pokémon, and gameplay mechanics.',
#      'metadata': {'YearOfRelease': 1999,
#       'Name': 'Pokémon Gold and Silver',
#       'Publisher': 'Nintendo',
#       'Genre': 'Role-playing',
#       'Description': 'Second-generation Pokémon games introducing new regions, Pokémon, and gameplay mechanics.',
#       'Platform': 'Game Boy Color'},
#      'distance': 0.5217366218566895,
#      'similarity': 0.47826337814331055},
#     {'rank': 2,
#      'id': 'Pokémon Ruby and Sapphire',
#      'document': '[Game Boy Advance] Pokémon Ruby and Sapphire (2002) - Third-generation Pokémon games set in the Hoenn region, featuring new Pokémon and double battles.',
#      'metadata': {'Description': 'Third-generation Pokémon games set in the Hoenn region, featuring new Pokémon and double battles.',
#       'Genre': 'Role-playing',
#       'YearOfRelease': 2002,
#       'Publisher': 'Nintendo',
#       'Platform': 'Game Boy Advance',
#       'Name': 'Pokémon Ruby and Sapphire'},
#      'distance': 0.5587925910949707,
#      'similarity': 0.4412074089050293},
#     {'rank': 3,
#      'id': 'Super Mario 64',
#      'document': "[Nintendo 64] Super Mario 64 (1996) - A groundbreaking 3D platformer that set new standards for the genre, featuring Mario's quest to rescue Princess Peach.",
#      'metadata': {'Genre': 'Platformer',
#       'Name': 'Super Mario 64',
#       'YearOfRelease': 1996,
#       'Description': "A groundbreaking 3D platformer that set new standards for the genre, featuring Mario's quest to rescue Princess Peach.",
#       'Platform': 'Nintendo 64',
#       'Publisher': 'Nintendo'},
#      'distance': 0.6806702613830566,
#      'similarity': 0.31932973861694336},
#     {'rank': 4,
#      'id': 'Super Mario World',
#      'document': '[Super Nintendo Entertainment System (SNES)] Super Mario World (1990) - A classic platformer where Mario embarks on a quest to save Princess Toadstool and Dinosaur Land from Bowser.',
#      'metadata': {'Platform': 'Super Nintendo Entertainment System (SNES)',
#       'YearOfRelease': 1990,
#       'Name': 'Super Mario World',
#       'Description': 'A classic platformer where Mario embarks on a quest to save Princess Toadstool and Dinosaur Land from Bowser.',
#       'Publisher': 'Nintendo',
#       'Genre': 'Platformer'},
#      'distance': 0.6869070529937744,
#      'similarity': 0.3130929470062256}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The context does not provide information about the platform on which Pokémon Red was launched.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'What platform was Pokemon Red launched on?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#   'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#    {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#    {'label': '[3]', 'source': 'Super Mario 64'},
#    {'label': '[4]', 'source': 'Super Mario World'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What platform was Pokemon Red launched on?',
#     'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[3]', 'source': 'Super Mario 64'},
#      {'label': '[4]', 'source': 'Super Mario World'}],
#     'confidence': 0.0}]},
#  {'question': 'What is Rockstar Games working on right now?',
#   'retrieval': {'query': 'What is Rockstar Games working on right now?',
#    'matches': [{'rank': 1,
#      'id': 'Grand Theft Auto: San Andreas',
#      'document': "[PlayStation 2] Grand Theft Auto: San Andreas (2004) - An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#      'metadata': {'Publisher': 'Rockstar Games',
#       'YearOfRelease': 2004,
#       'Description': "An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#       'Name': 'Grand Theft Auto: San Andreas',
#       'Platform': 'PlayStation 2',
#       'Genre': 'Action-adventure'},
#      'distance': 0.6077898740768433,
#      'similarity': 0.39221012592315674},
#     {'rank': 2,
#      'id': "Marvel's Spider-Man",
#      'document': "[PlayStation 4] Marvel's Spider-Man (2018) - An open-world superhero game that lets players swing through New York City as Spider-Man, battling iconic villains.",
#      'metadata': {'Publisher': 'Sony Interactive Entertainment',
#       'Description': 'An open-world superhero game that lets players swing through New York City as Spider-Man, battling iconic villains.',
#       'Name': "Marvel's Spider-Man",
#       'Platform': 'PlayStation 4',
#       'Genre': 'Action-adventure',
#       'YearOfRelease': 2018},
#      'distance': 0.6876252889633179,
#      'similarity': 0.31237471103668213},
#     {'rank': 3,
#      'id': 'Halo Infinite',
#      'document': "[Xbox Series X|S] Halo Infinite (2021) - The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#      'metadata': {'Genre': 'First-person shooter',
#       'Platform': 'Xbox Series X|S',
#       'Publisher': 'Xbox Game Studios',
#       'Description': "The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#       'Name': 'Halo Infinite',
#       'YearOfRelease': 2021},
#      'distance': 0.6922078728675842,
#      'similarity': 0.30779212713241577},
#     {'rank': 4,
#      'id': 'Minecraft',
#      'document': '[Xbox One] Minecraft (2014) - A sandbox game that allows players to build and explore infinite worlds, fostering creativity and adventure.',
#      'metadata': {'Platform': 'Xbox One',
#       'Publisher': 'Mojang Studios',
#       'YearOfRelease': 2014,
#       'Genre': 'Sandbox, Survival',
#       'Name': 'Minecraft',
#       'Description': 'A sandbox game that allows players to build and explore infinite worlds, fostering creativity and adventure.'},
#      'distance': 0.6929309964179993,
#      'similarity': 0.30706900358200073}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The context does not provide any information about what Rockstar Games is currently working on.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'What is Rockstar Games working on right now?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': "The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on Rockstar Games' current projects is available in the context provided.",
#   'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#    {'label': '[2]', 'source': "Marvel's Spider-Man"},
#    {'label': '[3]', 'source': 'Halo Infinite'},
#    {'label': '[4]', 'source': 'Minecraft'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What platform was Pokemon Red launched on?',
#     'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[3]', 'source': 'Super Mario 64'},
#      {'label': '[4]', 'source': 'Super Mario World'}],
#     'confidence': 0.0},
#    {'question': 'What is Rockstar Games working on right now?',
#     'answer': "The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on Rockstar Games' current projects is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man"},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Minecraft'}],
#     'confidence': 0.0}]},
#  {'question': 'Who made Dark Souls 3?',
#   'retrieval': {'query': 'Who made Dark Souls 3?',
#    'matches': [{'rank': 1,
#      'id': "Marvel's Spider-Man 2",
#      'document': "[PlayStation 5] Marvel's Spider-Man 2 (2023) - The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.",
#      'metadata': {'Description': 'The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.',
#       'Platform': 'PlayStation 5',
#       'Genre': 'Action-adventure',
#       'YearOfRelease': 2023,
#       'Name': "Marvel's Spider-Man 2",
#       'Publisher': 'Sony Interactive Entertainment'},
#      'distance': 0.724673867225647,
#      'similarity': 0.275326132774353},
#     {'rank': 2,
#      'id': 'Gran Turismo 5',
#      'document': '[PlayStation 3] Gran Turismo 5 (2010) - A comprehensive racing simulator featuring a vast selection of vehicles and tracks, with realistic driving physics.',
#      'metadata': {'Description': 'A comprehensive racing simulator featuring a vast selection of vehicles and tracks, with realistic driving physics.',
#       'Publisher': 'Sony Computer Entertainment',
#       'Name': 'Gran Turismo 5',
#       'Genre': 'Racing',
#       'Platform': 'PlayStation 3',
#       'YearOfRelease': 2010},
#      'distance': 0.7530101537704468,
#      'similarity': 0.24698984622955322},
#     {'rank': 3,
#      'id': 'Pokémon Ruby and Sapphire',
#      'document': '[Game Boy Advance] Pokémon Ruby and Sapphire (2002) - Third-generation Pokémon games set in the Hoenn region, featuring new Pokémon and double battles.',
#      'metadata': {'Platform': 'Game Boy Advance',
#       'Name': 'Pokémon Ruby and Sapphire',
#       'Description': 'Third-generation Pokémon games set in the Hoenn region, featuring new Pokémon and double battles.',
#       'Genre': 'Role-playing',
#       'YearOfRelease': 2002,
#       'Publisher': 'Nintendo'},
#      'distance': 0.7567516565322876,
#      'similarity': 0.2432483434677124},
#     {'rank': 4,
#      'id': "Marvel's Spider-Man",
#      'document': "[PlayStation 4] Marvel's Spider-Man (2018) - An open-world superhero game that lets players swing through New York City as Spider-Man, battling iconic villains.",
#      'metadata': {'Name': "Marvel's Spider-Man",
#       'Genre': 'Action-adventure',
#       'Platform': 'PlayStation 4',
#       'Description': 'An open-world superhero game that lets players swing through New York City as Spider-Man, battling iconic villains.',
#       'YearOfRelease': 2018,
#       'Publisher': 'Sony Interactive Entertainment'},
#      'distance': 0.7591599225997925,
#      'similarity': 0.24084007740020752}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The context does not provide information about who made Dark Souls 3.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'Who made Dark Souls 3?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': 'The provided context does not include information about who made Dark Souls 3. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the developer of Dark Souls 3 is available in the context provided.',
#   'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man 2"},
#    {'label': '[2]', 'source': 'Gran Turismo 5'},
#    {'label': '[3]', 'source': 'Pokémon Ruby and Sapphire'},
#    {'label': '[4]', 'source': "Marvel's Spider-Man"}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What platform was Pokemon Red launched on?',
#     'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[3]', 'source': 'Super Mario 64'},
#      {'label': '[4]', 'source': 'Super Mario World'}],
#     'confidence': 0.0},
#    {'question': 'What is Rockstar Games working on right now?',
#     'answer': "The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on Rockstar Games' current projects is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man"},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Minecraft'}],
#     'confidence': 0.0},
#    {'question': 'Who made Dark Souls 3?',
#     'answer': 'The provided context does not include information about who made Dark Souls 3. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the developer of Dark Souls 3 is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[2]', 'source': 'Gran Turismo 5'},
#      {'label': '[3]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[4]', 'source': "Marvel's Spider-Man"}],
#     'confidence': 0.0}]},
#  {'question': 'Who wrote the story for Nier Automata?',
#   'retrieval': {'query': 'Who wrote the story for Nier Automata?',
#    'matches': [{'rank': 1,
#      'id': 'Grand Theft Auto: San Andreas',
#      'document': "[PlayStation 2] Grand Theft Auto: San Andreas (2004) - An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#      'metadata': {'Name': 'Grand Theft Auto: San Andreas',
#       'Publisher': 'Rockstar Games',
#       'YearOfRelease': 2004,
#       'Platform': 'PlayStation 2',
#       'Description': "An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#       'Genre': 'Action-adventure'},
#      'distance': 0.738815188407898,
#      'similarity': 0.26118481159210205},
#     {'rank': 2,
#      'id': "Marvel's Spider-Man 2",
#      'document': "[PlayStation 5] Marvel's Spider-Man 2 (2023) - The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.",
#      'metadata': {'Description': 'The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.',
#       'Platform': 'PlayStation 5',
#       'Publisher': 'Sony Interactive Entertainment',
#       'Genre': 'Action-adventure',
#       'Name': "Marvel's Spider-Man 2",
#       'YearOfRelease': 2023},
#      'distance': 0.7544634342193604,
#      'similarity': 0.24553656578063965},
#     {'rank': 3,
#      'id': 'Mario Kart 8 Deluxe',
#      'document': '[Nintendo Switch] Mario Kart 8 Deluxe (2017) - An enhanced version of Mario Kart 8, featuring new characters, tracks, and improved gameplay mechanics.',
#      'metadata': {'Description': 'An enhanced version of Mario Kart 8, featuring new characters, tracks, and improved gameplay mechanics.',
#       'Publisher': 'Nintendo',
#       'Platform': 'Nintendo Switch',
#       'YearOfRelease': 2017,
#       'Genre': 'Racing',
#       'Name': 'Mario Kart 8 Deluxe'},
#      'distance': 0.7817124128341675,
#      'similarity': 0.21828758716583252},
#     {'rank': 4,
#      'id': 'Halo Infinite',
#      'document': "[Xbox Series X|S] Halo Infinite (2021) - The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#      'metadata': {'Platform': 'Xbox Series X|S',
#       'Genre': 'First-person shooter',
#       'Description': "The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#       'YearOfRelease': 2021,
#       'Publisher': 'Xbox Game Studios',
#       'Name': 'Halo Infinite'},
#      'distance': 0.7901052236557007,
#      'similarity': 0.20989477634429932}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The context does not provide information about who wrote the story for Nier Automata.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'Who wrote the story for Nier Automata?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': 'The provided context does not include information about who wrote the story for Nier Automata. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the story writer for Nier Automata is available in the context provided.',
#   'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#    {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#    {'label': '[3]', 'source': 'Mario Kart 8 Deluxe'},
#    {'label': '[4]', 'source': 'Halo Infinite'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What platform was Pokemon Red launched on?',
#     'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[3]', 'source': 'Super Mario 64'},
#      {'label': '[4]', 'source': 'Super Mario World'}],
#     'confidence': 0.0},
#    {'question': 'What is Rockstar Games working on right now?',
#     'answer': "The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on Rockstar Games' current projects is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man"},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Minecraft'}],
#     'confidence': 0.0},
#    {'question': 'Who made Dark Souls 3?',
#     'answer': 'The provided context does not include information about who made Dark Souls 3. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the developer of Dark Souls 3 is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[2]', 'source': 'Gran Turismo 5'},
#      {'label': '[3]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[4]', 'source': "Marvel's Spider-Man"}],
#     'confidence': 0.0},
#    {'question': 'Who wrote the story for Nier Automata?',
#     'answer': 'The provided context does not include information about who wrote the story for Nier Automata. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the story writer for Nier Automata is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Mario Kart 8 Deluxe'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0}]},
#  {'question': 'What is the most recent Star Ocean game?',
#   'retrieval': {'query': 'What is the most recent Star Ocean game?',
#    'matches': [{'rank': 1,
#      'id': 'Pokémon Ruby and Sapphire',
#      'document': '[Game Boy Advance] Pokémon Ruby and Sapphire (2002) - Third-generation Pokémon games set in the Hoenn region, featuring new Pokémon and double battles.',
#      'metadata': {'Platform': 'Game Boy Advance',
#       'Genre': 'Role-playing',
#       'YearOfRelease': 2002,
#       'Description': 'Third-generation Pokémon games set in the Hoenn region, featuring new Pokémon and double battles.',
#       'Name': 'Pokémon Ruby and Sapphire',
#       'Publisher': 'Nintendo'},
#      'distance': 0.6724261045455933,
#      'similarity': 0.32757389545440674},
#     {'rank': 2,
#      'id': 'Pokémon Gold and Silver',
#      'document': '[Game Boy Color] Pokémon Gold and Silver (1999) - Second-generation Pokémon games introducing new regions, Pokémon, and gameplay mechanics.',
#      'metadata': {'Description': 'Second-generation Pokémon games introducing new regions, Pokémon, and gameplay mechanics.',
#       'Platform': 'Game Boy Color',
#       'Genre': 'Role-playing',
#       'Publisher': 'Nintendo',
#       'YearOfRelease': 1999,
#       'Name': 'Pokémon Gold and Silver'},
#      'distance': 0.6799178123474121,
#      'similarity': 0.3200821876525879},
#     {'rank': 3,
#      'id': 'Halo Infinite',
#      'document': "[Xbox Series X|S] Halo Infinite (2021) - The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#      'metadata': {'Description': "The latest installment in the Halo franchise, featuring Master Chief's return in a new open-world setting.",
#       'Name': 'Halo Infinite',
#       'Publisher': 'Xbox Game Studios',
#       'Genre': 'First-person shooter',
#       'Platform': 'Xbox Series X|S',
#       'YearOfRelease': 2021},
#      'distance': 0.7032546401023865,
#      'similarity': 0.2967453598976135},
#     {'rank': 4,
#      'id': 'Gran Turismo 5',
#      'document': '[PlayStation 3] Gran Turismo 5 (2010) - A comprehensive racing simulator featuring a vast selection of vehicles and tracks, with realistic driving physics.',
#      'metadata': {'Name': 'Gran Turismo 5',
#       'Platform': 'PlayStation 3',
#       'Publisher': 'Sony Computer Entertainment',
#       'Genre': 'Racing',
#       'Description': 'A comprehensive racing simulator featuring a vast selection of vehicles and tracks, with realistic driving physics.',
#       'YearOfRelease': 2010},
#      'distance': 0.7101805210113525,
#      'similarity': 0.28981947898864746}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The context does not provide information about the most recent Star Ocean game.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'What is the most recent Star Ocean game?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': 'The provided context does not include any information about the most recent Star Ocean game. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the most recent Star Ocean game is available in the context provided.',
#   'citations': [{'label': '[1]', 'source': 'Pokémon Ruby and Sapphire'},
#    {'label': '[2]', 'source': 'Pokémon Gold and Silver'},
#    {'label': '[3]', 'source': 'Halo Infinite'},
#    {'label': '[4]', 'source': 'Gran Turismo 5'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What platform was Pokemon Red launched on?',
#     'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[3]', 'source': 'Super Mario 64'},
#      {'label': '[4]', 'source': 'Super Mario World'}],
#     'confidence': 0.0},
#    {'question': 'What is Rockstar Games working on right now?',
#     'answer': "The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on Rockstar Games' current projects is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man"},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Minecraft'}],
#     'confidence': 0.0},
#    {'question': 'Who made Dark Souls 3?',
#     'answer': 'The provided context does not include information about who made Dark Souls 3. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the developer of Dark Souls 3 is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[2]', 'source': 'Gran Turismo 5'},
#      {'label': '[3]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[4]', 'source': "Marvel's Spider-Man"}],
#     'confidence': 0.0},
#    {'question': 'Who wrote the story for Nier Automata?',
#     'answer': 'The provided context does not include information about who wrote the story for Nier Automata. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the story writer for Nier Automata is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Mario Kart 8 Deluxe'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What is the most recent Star Ocean game?',
#     'answer': 'The provided context does not include any information about the most recent Star Ocean game. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the most recent Star Ocean game is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[2]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Gran Turismo 5'}],
#     'confidence': 0.0}]},
#  {'question': 'Who is the main character of FFVII?',
#   'retrieval': {'query': 'Who is the main character of FFVII?',
#    'matches': [{'rank': 1,
#      'id': 'Super Mario World',
#      'document': '[Super Nintendo Entertainment System (SNES)] Super Mario World (1990) - A classic platformer where Mario embarks on a quest to save Princess Toadstool and Dinosaur Land from Bowser.',
#      'metadata': {'Publisher': 'Nintendo',
#       'Genre': 'Platformer',
#       'YearOfRelease': 1990,
#       'Platform': 'Super Nintendo Entertainment System (SNES)',
#       'Name': 'Super Mario World',
#       'Description': 'A classic platformer where Mario embarks on a quest to save Princess Toadstool and Dinosaur Land from Bowser.'},
#      'distance': 0.7489293813705444,
#      'similarity': 0.25107061862945557},
#     {'rank': 2,
#      'id': 'Super Mario 64',
#      'document': "[Nintendo 64] Super Mario 64 (1996) - A groundbreaking 3D platformer that set new standards for the genre, featuring Mario's quest to rescue Princess Peach.",
#      'metadata': {'Publisher': 'Nintendo',
#       'YearOfRelease': 1996,
#       'Description': "A groundbreaking 3D platformer that set new standards for the genre, featuring Mario's quest to rescue Princess Peach.",
#       'Name': 'Super Mario 64',
#       'Platform': 'Nintendo 64',
#       'Genre': 'Platformer'},
#      'distance': 0.7736755609512329,
#      'similarity': 0.2263244390487671},
#     {'rank': 3,
#      'id': 'Grand Theft Auto: San Andreas',
#      'document': "[PlayStation 2] Grand Theft Auto: San Andreas (2004) - An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#      'metadata': {'Description': "An expansive open-world game set in the fictional state of San Andreas, following the story of Carl 'CJ' Johnson.",
#       'Genre': 'Action-adventure',
#       'Name': 'Grand Theft Auto: San Andreas',
#       'Platform': 'PlayStation 2',
#       'YearOfRelease': 2004,
#       'Publisher': 'Rockstar Games'},
#      'distance': 0.7836024165153503,
#      'similarity': 0.21639758348464966},
#     {'rank': 4,
#      'id': 'Super Smash Bros. Melee',
#      'document': '[GameCube] Super Smash Bros. Melee (2001) - A crossover fighting game featuring characters from various Nintendo franchises battling it out in dynamic arenas.',
#      'metadata': {'Publisher': 'Nintendo',
#       'Name': 'Super Smash Bros. Melee',
#       'Platform': 'GameCube',
#       'Genre': 'Fighting',
#       'Description': 'A crossover fighting game featuring characters from various Nintendo franchises battling it out in dynamic arenas.',
#       'YearOfRelease': 2001},
#      'distance': 0.7946597337722778,
#      'similarity': 0.20534026622772217}],
#    'source': 'vector_db'},
#   'memory_context': [],
#   'evaluation': {'summary': 'The main character of Final Fantasy VII is not mentioned in the provided context.',
#    'confidence': 0.0,
#    'needs_web_search': True,
#    'supporting_fact_ids': []},
#   'needs_web_search': True,
#   'web_results': {'query': 'Who is the main character of FFVII?',
#    'error': '422 Client Error: Unprocessable Entity for url: https://api.tavily.com/search',
#    'results': []},
#   'answer': 'The provided context does not include information about the main character of Final Fantasy VII (FFVII). Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the main character of FFVII is available in the context provided.',
#   'citations': [{'label': '[1]', 'source': 'Super Mario World'},
#    {'label': '[2]', 'source': 'Super Mario 64'},
#    {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#    {'label': '[4]', 'source': 'Super Smash Bros. Melee'}],
#   'confidence': 0.0,
#   'history': [{'question': 'Who developed FIFA 21?',
#     'answer': 'The provided context does not include information about the developer of FIFA 21. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on FIFA 21 developer is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Halo Infinite'},
#      {'label': '[2]', 'source': 'Minecraft'},
#      {'label': '[3]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[4]', 'source': 'Mario Kart 8 Deluxe'}],
#     'confidence': 0.0},
#    {'question': 'When was God of War Ragnarok released?',
#     'answer': "The provided context does not include information about the release date of God of War Ragnarok. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on God of War Ragnarok's release date is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man"},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What platform was Pokemon Red launched on?',
#     'answer': 'The provided context does not include information about the platform on which Pokémon Red was launched. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the platform for Pokémon Red is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[2]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[3]', 'source': 'Super Mario 64'},
#      {'label': '[4]', 'source': 'Super Mario World'}],
#     'confidence': 0.0},
#    {'question': 'What is Rockstar Games working on right now?',
#     'answer': "The provided context does not include any information about what Rockstar Games is currently working on. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on Rockstar Games' current projects is available in the context provided.",
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man"},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Minecraft'}],
#     'confidence': 0.0},
#    {'question': 'Who made Dark Souls 3?',
#     'answer': 'The provided context does not include information about who made Dark Souls 3. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the developer of Dark Souls 3 is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[2]', 'source': 'Gran Turismo 5'},
#      {'label': '[3]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[4]', 'source': "Marvel's Spider-Man"}],
#     'confidence': 0.0},
#    {'question': 'Who wrote the story for Nier Automata?',
#     'answer': 'The provided context does not include information about who wrote the story for Nier Automata. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the story writer for Nier Automata is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[2]', 'source': "Marvel's Spider-Man 2"},
#      {'label': '[3]', 'source': 'Mario Kart 8 Deluxe'},
#      {'label': '[4]', 'source': 'Halo Infinite'}],
#     'confidence': 0.0},
#    {'question': 'What is the most recent Star Ocean game?',
#     'answer': 'The provided context does not include any information about the most recent Star Ocean game. Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the most recent Star Ocean game is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Pokémon Ruby and Sapphire'},
#      {'label': '[2]', 'source': 'Pokémon Gold and Silver'},
#      {'label': '[3]', 'source': 'Halo Infinite'},
#      {'label': '[4]', 'source': 'Gran Turismo 5'}],
#     'confidence': 0.0},
#    {'question': 'Who is the main character of FFVII?',
#     'answer': 'The provided context does not include information about the main character of Final Fantasy VII (FFVII). Therefore, I cannot answer your question based on the available data.\n\nKey facts:\n- No information on the main character of FFVII is available in the context provided.',
#     'citations': [{'label': '[1]', 'source': 'Super Mario World'},
#      {'label': '[2]', 'source': 'Super Mario 64'},
#      {'label': '[3]', 'source': 'Grand Theft Auto: San Andreas'},
#      {'label': '[4]', 'source': 'Super Smash Bros. Melee'}],
#     'confidence': 0.0}]}]

# %% [markdown]
# ### (Optional) Advanced

# %%
# Optional: Inspect long-term memory fragments after running the agent.
memory_store.search("Rockstar Games")
